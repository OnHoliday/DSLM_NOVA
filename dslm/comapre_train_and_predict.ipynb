# %%
import pickle

# %%
with open('cnn_1_layer_init.pickle', 'rb') as f:
    init_cnn_layer = pickle.load(f)

# %%
with open('cnn_1_layer_predict.pickle', 'rb') as f:
    pred_cnn_layer = pickle.load(f)

# %%
init_cnn_layer

# %%
dir(init_cnn_layer[0])
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_calculate_output',
#  '_calculate_weighted_input',
#  '_initialize_parameters',
#  'activation_function',
#  'cache_weighted_input',
#  'calculate',
#  'calculate2',
#  'convolv',
#  'convolv2',
#  'dimenstions',
#  'filter',
#  'free_semantics',
#  'free_weighted_input',
#  'get_sizes',
#  'get_weighted_input',
#  'incremental_semantics_computation',
#  'input_connections',
#  'input_length',
#  'input_width',
#  'kernel_size',
#  'nr_of_channel',
#  'output_length',
#  'output_width',
#  'semantics',
#  'set_previous_bias',
# ...

# %%
init_cnn_layer[0].semantics.shape
# Out:
# (30, 30, 3, 50000)

# %%
pred_cnn_layer

# %%
pred_cnn_layer[0].semantics
# Out:
# array([[[[-1.24216991e+01,  2.62982995e-01,  1.55566864e+01, ...,
#           -9.30399160e+00,  8.10185848e+00,  1.25297524e+01],
#          [-1.36343834e+01,  7.82098418e-01,  1.50360821e+01, ...,
#            6.19567891e+00,  9.57913806e+00,  1.19312758e+01],
#          [-1.23710927e+01,  1.31459499e+00,  1.40182939e+01, ...,
#            1.25582758e+01,  1.21879496e+01,  1.22779207e+01]],
#
#         [[-1.10903291e+01, -5.91713652e-01,  1.56116732e+01, ...,
#           -9.78365312e+00,  7.93430706e+00,  1.30051320e+01],
#          [-1.33767568e+01, -7.27898684e-01,  1.51036375e+01, ...,
#            6.28162014e+00,  9.47927978e+00,  1.26473039e+01],
#          [-1.28244229e+01, -2.96797368e-01,  1.40725100e+01, ...,
#            1.27134721e+01,  1.20922712e+01,  1.30929378e+01]],
#
#         [[-7.88070612e+00, -6.21066196e-01,  1.56163804e+01, ...,
#           -9.61414075e+00,  7.75945246e+00,  1.28841526e+01],
#          [-1.14731479e+01, -6.94073652e-01,  1.51217777e+01, ...,
# ...

# %%
import numpy as np

# %%
np.random.randint(1, 5, (1, 2, 3, 4))
# Out:
# array([[[[1, 2, 3, 3],
#          [4, 1, 3, 1],
#          [2, 2, 3, 1]],
#
#         [[4, 3, 3, 4],
#          [2, 2, 1, 3],
#          [2, 3, 2, 3]]]])
